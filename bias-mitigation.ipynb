# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bank-account-fraud-dataset-neurips-2022/Base.csv
# /kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant IV.csv
# /kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant V.csv
# /kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant I.csv
# /kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant III.csv
# /kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant II.csv

# %%
import pandas as pd

# Import the datasets
base = pd.read_csv('/kaggle/input/bank-account-fraud-dataset-neurips-2022/Base.csv')
variant_1 = pd.read_csv('/kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant I.csv')
variant_2 = pd.read_csv('/kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant II.csv')
variant_3 = pd.read_csv('/kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant III.csv')
variant_4 = pd.read_csv('/kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant IV.csv')
variant_5 = pd.read_csv('/kaggle/input/bank-account-fraud-dataset-neurips-2022/Variant V.csv')

# %%
# Install and import LightGBM and XGBoost
# !pip install lightgbm xgboost

# !pip install fairlearn aif360
# Out:
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.14.1)
# Collecting fairlearn
#   Downloading fairlearn-0.11.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting aif360
#   Downloading aif360-0.6.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24.4 in /opt/conda/lib/python3.10/site-packages (from fairlearn) (1.26.4)
# Requirement already satisfied: pandas>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from fairlearn) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.2.1 in /opt/conda/lib/python3.10/site-packages (from fairlearn) (1.2.2)
# Requirement already satisfied: scipy>=1.9.3 in /opt/conda/lib/python3.10/site-packages (from fairlearn) (1.14.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from aif360) (3.7.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.3->fairlearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.3->fairlearn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.3->fairlearn) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.2.1->fairlearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.2.1->fairlearn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->aif360) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.3->fairlearn) (1.16.0)
# Downloading fairlearn-0.11.0-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.3/232.3 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Downloading aif360-0.6.1-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 13.0 MB/s eta 0:00:00
# Installing collected packages: fairlearn, aif360
# Successfully installed aif360-0.6.1 fairlearn-0.11.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.utils import resample
from imblearn.over_sampling import SMOTENC

# Existing imports
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Fairness libraries
from aif360.datasets import BinaryLabelDataset
from aif360.algorithms.preprocessing import Reweighing

datasets = {
    "Base": base,
    "Variant I": variant_1,
    "Variant II": variant_2,
    "Variant III": variant_3,
    "Variant IV": variant_4,
    "Variant V": variant_5,
}

train_test_data = {}

# Define the sensitive attribute
sensitive_attribute = 'employment_status'  # Replace with your sensitive attribute

# Process each dataset
for name, data_raw in datasets.items():
    print(f"Processing Dataset: {name}")
    
    # Verify if target column exists
    target_variable = 'fraud_bool'
    if target_variable not in data_raw.columns:
        raise ValueError(f"'{target_variable}' column not found in {name} dataset. Please check the column name.")

    # Balance the dataset by downsampling the majority class
    df_fraud = data_raw[data_raw[target_variable] == 1]
    df_non_fraud = data_raw[data_raw[target_variable] == 0]
    
    df_non_fraud_downsampled = resample(df_non_fraud,
                                        replace=False,
                                        n_samples=len(df_fraud),
                                        random_state=42)
    
    # Combine the minority and downsampled majority class
    df_balanced = pd.concat([df_fraud, df_non_fraud_downsampled])
    
    # Shuffle the dataset and reset the index
    df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)
    
    # Verify that 'month' column exists
    if 'month' not in df_balanced.columns:
        raise ValueError(f"'month' column not found in {name} dataset. Please check the column name.")

    # Split the data into train and test based on the "month" feature
    train_data = df_balanced[df_balanced['month'].between(0, 5)]
    test_data = df_balanced[df_balanced['month'].between(6, 7)]
    
    # Drop the "month" feature from train and test sets
    train_data = train_data.drop(columns=['month'])
    test_data = test_data.drop(columns=['month'])
    
    # Reset index
    train_data.reset_index(drop=True, inplace=True)
    test_data.reset_index(drop=True, inplace=True)
    
    # Separate features and target variable
    X_train = train_data.drop(columns=[target_variable])
    y_train = train_data[target_variable]
    X_test = test_data.drop(columns=[target_variable])
    y_test = test_data[target_variable]
    
    # Check if the sensitive attribute exists
    if sensitive_attribute not in X_train.columns:
        raise ValueError(f"'{sensitive_attribute}' column not found in {name} dataset. Please check the column name.")

    # Identify categorical features (including the sensitive attribute)
    categorical_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
    # Ensure the sensitive attribute is included in categorical_features
    if sensitive_attribute not in categorical_features:
        categorical_features.append(sensitive_attribute)
    
    # Get indices of categorical features
    categorical_features_indices = [X_train.columns.get_loc(col) for col in categorical_features]

    # Apply OrdinalEncoder to categorical features (including sensitive attribute)
    ordinal_encoder = OrdinalEncoder(dtype=np.int32)
    X_train_encoded = X_train.copy()
    X_test_encoded = X_test.copy()

    if categorical_features:
        # Fit the encoder on combined data to ensure all categories are captured
        combined_categories = pd.concat([X_train_encoded[categorical_features], X_test_encoded[categorical_features]])
        ordinal_encoder.fit(combined_categories)

        X_train_encoded[categorical_features] = ordinal_encoder.transform(X_train_encoded[categorical_features])
        X_test_encoded[categorical_features] = ordinal_encoder.transform(X_test_encoded[categorical_features])

    # Apply SMOTENC to X_train_encoded and y_train
    smote_nc = SMOTENC(categorical_features=categorical_features_indices, random_state=42)
    X_train_resampled, y_train_resampled = smote_nc.fit_resample(X_train_encoded, y_train)

    # Ensure that categorical features remain integer after SMOTENC
    for col in categorical_features:
        X_train_resampled[col] = X_train_resampled[col].round(0).astype(int)

    # Extract the sensitive attribute after resampling (but do not drop it yet)
    S_train_resampled = X_train_resampled[sensitive_attribute]
    # We'll drop the sensitive attribute later

    # For X_test_encoded, extract the encoded sensitive attribute
    S_test_encoded = X_test_encoded[sensitive_attribute]

    # Proceed with further preprocessing (e.g., scaling numerical features)
    # Exclude categorical features (including the sensitive attribute) from scaling
    numerical_features = X_train_resampled.columns.difference(categorical_features)

    preprocessor = StandardScaler()

    X_train_scaled = preprocessor.fit_transform(X_train_resampled[numerical_features])
    X_test_scaled = preprocessor.transform(X_test_encoded[numerical_features])

    # Convert scaled numerical features back to DataFrames
    X_train_scaled = pd.DataFrame(X_train_scaled, columns=numerical_features)
    X_test_scaled = pd.DataFrame(X_test_scaled, columns=numerical_features)

    # Combine scaled numerical features with categorical features (including sensitive attribute)
    X_train_processed = pd.concat([X_train_scaled.reset_index(drop=True),
                                   X_train_resampled[categorical_features].reset_index(drop=True)], axis=1)
    X_test_processed = pd.concat([X_test_scaled.reset_index(drop=True),
                                  X_test_encoded[categorical_features].reset_index(drop=True)], axis=1)

    # Now drop the sensitive attribute from features
    X_train_processed_no_sensitive = X_train_processed.drop(columns=[sensitive_attribute])
    X_test_processed_no_sensitive = X_test_processed.drop(columns=[sensitive_attribute])

    # Ensure that S_train_resampled and S_test_encoded are integer arrays
    S_train_resampled = S_train_resampled.reset_index(drop=True).astype(int).values.ravel()
    S_test_resampled = S_test_encoded.reset_index(drop=True).astype(int).values.ravel()

    # Reweighing using AIF360
    # Combine features and labels for AIF360 dataset
    X_train_df = X_train_processed.copy()
    X_train_df['label'] = y_train_resampled.reset_index(drop=True)

    aif_train_dataset = BinaryLabelDataset(
        favorable_label=1,
        unfavorable_label=0,
        df=X_train_df,
        label_names=['label'],
        protected_attribute_names=[sensitive_attribute]
    )

    RW = Reweighing(
        unprivileged_groups=[{sensitive_attribute: 0}],
        privileged_groups=[{sensitive_attribute: 1}]
    )
    aif_train_dataset_transf = RW.fit_transform(aif_train_dataset)

    # Retrieve sample weights
    sample_weights = aif_train_dataset_transf.instance_weights

    # Update X_train_processed and y_train_resampled
    X_train_processed = pd.DataFrame(aif_train_dataset_transf.features, columns=X_train_processed.columns)
    y_train_resampled = aif_train_dataset_transf.labels.ravel()
    S_train_resampled = aif_train_dataset_transf.protected_attributes.ravel()

    # Now drop the sensitive attribute from X_train_processed
    X_train_processed_no_sensitive = X_train_processed.drop(columns=[sensitive_attribute])

    # Store transformed datasets
    train_test_data[name] = {
        'X_train': X_train_processed_no_sensitive,
        'X_test': X_test_processed_no_sensitive,
        'y_train': y_train_resampled,
        'y_test': y_test.reset_index(drop=True),
        'S_train': S_train_resampled.astype(int),
        'S_test': S_test_resampled.astype(int),
        'sample_weights': sample_weights,
        'X_test_raw': X_test.reset_index(drop=True),
        'preprocessor': preprocessor  # Save preprocessor for inverse transform or further processing
    }

print("Data Transformation Completed for All Variants.")
# Out:
# Processing Dataset: Base
# Processing Dataset: Variant I
# Processing Dataset: Variant II
# Processing Dataset: Variant III
# Processing Dataset: Variant IV
# Processing Dataset: Variant V
# Data Transformation Completed for All Variants.

# %%
# Model Training and Evaluation with Bias Mitigation

# Import necessary libraries
from sklearn.base import clone
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report, roc_auc_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from fairlearn.metrics import demographic_parity_difference, equalized_odds_difference
from fairlearn.postprocessing import ThresholdOptimizer
from aif360.algorithms.inprocessing import AdversarialDebiasing

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

# Define your models
models = {
    "Logistic Regression": LogisticRegression(random_state=42, max_iter=1000),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gaussian Naive Bayes": GaussianNB(),
    "Bernoulli Naive Bayes": BernoulliNB(),
    "SVM": SVC(probability=True, random_state=42),
    "Neural Network": MLPClassifier(random_state=42, max_iter=300),
    "LightGBM": LGBMClassifier(random_state=42),
    "XGBoost": XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss'),
}

trained_models = {}
all_metrics_results = []
bias_metrics_results = []

# Define the sensitive attribute (make sure it matches the one used in preprocessing)
sensitive_attribute = 'employment_status'  # Replace with your sensitive attribute

# Iterate through each dataset and model to train and evaluate them with bias mitigation
for dataset_name, data in train_test_data.items():
    print(f"\nProcessing Dataset: {dataset_name}")

    # Prepare test data for AIF360
    X_test_df = data['X_test'].copy()
    X_test_df[sensitive_attribute] = pd.Series(data['S_test']).reset_index(drop=True)
    X_test_df['label'] = pd.Series(data['y_test']).reset_index(drop=True)

    aif_test_dataset = BinaryLabelDataset(
        favorable_label=1,
        unfavorable_label=0,
        df=X_test_df,
        label_names=['label'],
        protected_attribute_names=[sensitive_attribute]
    )

    for model_name, model in models.items():
        print(f"\nTraining and Evaluating {model_name} on {dataset_name} dataset with Bias Mitigation...")

        # Clone the model
        base_estimator = clone(model)

        # Check if the model supports sample_weight
        if 'sample_weight' in base_estimator.fit.__code__.co_varnames:
            # Models supporting sample_weight - use reweighing
            base_estimator.fit(data['X_train'], data['y_train'], sample_weight=data['sample_weights'])
            y_test_pred = base_estimator.predict(data['X_test'])
            if hasattr(base_estimator, "predict_proba"):
                y_test_prob = base_estimator.predict_proba(data['X_test'])[:, 1]
            else:
                y_test_prob = None
        else:
            # Models not supporting sample_weight
            # Use in-processing or post-processing techniques

            # In-processing with Adversarial Debiasing (if applicable)
            if model_name == "Neural Network":
                # Prepare training data for AIF360
                X_train_df = data['X_train'].copy()
                X_train_df[sensitive_attribute] = pd.Series(data['S_train']).reset_index(drop=True)
                X_train_df['label'] = pd.Series(data['y_train']).reset_index(drop=True)

                aif_train_dataset = BinaryLabelDataset(
                    favorable_label=1,
                    unfavorable_label=0,
                    df=X_train_df,
                    label_names=['label'],S
                    protected_attribute_names=[sensitive_attribute]
                )

                # **Reset the default graph to avoid variable conflicts**
                tf.reset_default_graph()

                # Create TensorFlow session
                sess = tf.Session()

                # Initialize Adversarial Debiasing model
                adv_debiasing = AdversarialDebiasing(
                    privileged_groups=[{sensitive_attribute: 1}],
                    unprivileged_groups=[{sensitive_attribute: 0}],
                    scope_name='adv_debiasing',
                    sess=sess,
                    num_epochs=50
                )

                # Train the model
                adv_debiasing.fit(aif_train_dataset)

                # Make predictions
                aif_test_pred = adv_debiasing.predict(aif_test_dataset)
                y_test_pred = aif_test_pred.labels.ravel()
                y_test_prob = None  # Probabilities not available
                sess.close()
            else:
                # Post-processing with ThresholdOptimizer
                base_estimator.fit(data['X_train'], data['y_train'])
                
                # Apply Threshold Optimizer
                postprocess_est = ThresholdOptimizer(
                    estimator=base_estimator,
                    constraints="equalized_odds",  # or "demographic_parity"
                    prefit=True
                )
                postprocess_est.fit(
                    data['X_train'],
                    data['y_train'],
                    sensitive_features=data['S_train']
                )
                y_test_pred = postprocess_est.predict(
                    data['X_test'],
                    sensitive_features=data['S_test']
                )
                if hasattr(base_estimator, "predict_proba"):
                    y_test_prob = base_estimator.predict_proba(data['X_test'])[:, 1]
                else:
                    y_test_prob = None

        # Calculate metrics
        cm = confusion_matrix(data['y_test'], y_test_pred)
        report = classification_report(data['y_test'], y_test_pred, output_dict=True)

        # Calculate ROC-AUC score
        if y_test_prob is not None:
            roc_auc = roc_auc_score(data['y_test'], y_test_prob)
        else:
            roc_auc = None  # Use None when ROC-AUC is not available

        # Print Confusion Matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
        plt.title(f"Confusion Matrix for {model_name} on {dataset_name} Dataset with Bias Mitigation")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.show()

        # Print Classification Report and ROC-AUC
        print(f"Classification Report for {model_name} on {dataset_name} Dataset with Bias Mitigation:")
        print(classification_report(data['y_test'], y_test_pred))

        if roc_auc is not None:
            print(f"ROC-AUC Score for {model_name} on {dataset_name} Dataset: {roc_auc:.2f}")
        else:
            print(f"ROC-AUC Score for {model_name} on {dataset_name} Dataset: Not Applicable")

        # Evaluate fairness metrics
        dp_diff = demographic_parity_difference(
            y_true=data['y_test'],
            y_pred=y_test_pred,
            sensitive_features=data['S_test']
        )

        eo_diff = equalized_odds_difference(
            y_true=data['y_test'],
            y_pred=y_test_pred,
            sensitive_features=data['S_test']
        )

        # Store all metrics results
        all_metrics_results.append({
            'Dataset': dataset_name,
            'Model': model_name,
            'Accuracy': accuracy_score(data['y_test'], y_test_pred),
            'F1 Score': f1_score(data['y_test'], y_test_pred),
            'ROC-AUC Score': roc_auc if roc_auc is not None else 'N/A',
            'Demographic Parity Difference': dp_diff,
            'Equalized Odds Difference': eo_diff
        })

        # Store bias metrics separately for plotting
        bias_metrics_results.append({
            'Dataset': dataset_name,
            'Model': model_name,
            'Demographic Parity Difference': dp_diff,
            'Equalized Odds Difference': eo_diff
        })

print("\nModel Training and Evaluation Completed.")
# Out:
# Processing Dataset: Base
#
# Training and Evaluating Logistic Regression on Base dataset with Bias Mitigation...
# Classification Report for Logistic Regression on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.71      0.82      0.76      2246
#            1       0.84      0.74      0.78      2878
#
#     accuracy                           0.77      5124
#    macro avg       0.77      0.78      0.77      5124
# weighted avg       0.78      0.77      0.77      5124
#
# ROC-AUC Score for Logistic Regression on Base Dataset: 0.86
#
# Training and Evaluating KNN on Base dataset with Bias Mitigation...
# Classification Report for KNN on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.63      0.76      0.69      2246
#            1       0.77      0.65      0.70      2878
#
#     accuracy                           0.70      5124
#    macro avg       0.70      0.70      0.70      5124
# weighted avg       0.71      0.70      0.70      5124
#
# ROC-AUC Score for KNN on Base Dataset: 0.81
#
# Training and Evaluating Random Forest on Base dataset with Bias Mitigation...
# Classification Report for Random Forest on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77      2246
#            1       0.83      0.79      0.81      2878
#
#     accuracy                           0.79      5124
#    macro avg       0.79      0.79      0.79      5124
# weighted avg       0.79      0.79      0.79      5124
#
# ROC-AUC Score for Random Forest on Base Dataset: 0.87
#
# Training and Evaluating Gaussian Naive Bayes on Base dataset with Bias Mitigation...
# Classification Report for Gaussian Naive Bayes on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      2246
#            1       0.81      0.75      0.78      2878
#
#     accuracy                           0.76      5124
#    macro avg       0.76      0.76      0.76      5124
# weighted avg       0.77      0.76      0.76      5124
#
# ROC-AUC Score for Gaussian Naive Bayes on Base Dataset: 0.82
#
# Training and Evaluating Bernoulli Naive Bayes on Base dataset with Bias Mitigation...
# Classification Report for Bernoulli Naive Bayes on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73      2246
#            1       0.79      0.80      0.79      2878
#
#     accuracy                           0.76      5124
#    macro avg       0.76      0.76      0.76      5124
# weighted avg       0.76      0.76      0.76      5124
#
# ROC-AUC Score for Bernoulli Naive Bayes on Base Dataset: 0.83
#
# Training and Evaluating SVM on Base dataset with Bias Mitigation...
# Classification Report for SVM on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77      2246
#            1       0.82      0.81      0.82      2878
#
#     accuracy                           0.80      5124
#    macro avg       0.79      0.79      0.79      5124
# weighted avg       0.80      0.80      0.80      5124
#
# ROC-AUC Score for SVM on Base Dataset: 0.87
#
# Training and Evaluating Neural Network on Base dataset with Bias Mitigation...
# epoch 0; iter: 0; batch classifier loss: 0.717741; batch adversarial loss: 0.874053
# epoch 1; iter: 0; batch classifier loss: 0.425421; batch adversarial loss: 0.875943
# epoch 2; iter: 0; batch classifier loss: 0.412089; batch adversarial loss: 0.773019
# epoch 3; iter: 0; batch classifier loss: 0.438752; batch adversarial loss: 0.770435
# epoch 4; iter: 0; batch classifier loss: 0.467227; batch adversarial loss: 0.760500
# epoch 5; iter: 0; batch classifier loss: 0.439724; batch adversarial loss: 0.737972
# epoch 6; iter: 0; batch classifier loss: 0.430668; batch adversarial loss: 0.718667
# epoch 7; iter: 0; batch classifier loss: 0.390602; batch adversarial loss: 0.693781
# epoch 8; iter: 0; batch classifier loss: 0.445046; batch adversarial loss: 0.705073
# epoch 9; iter: 0; batch classifier loss: 0.416643; batch adversarial loss: 0.688272
# epoch 10; iter: 0; batch classifier loss: 0.360564; batch adversarial loss: 0.686927
# epoch 11; iter: 0; batch classifier loss: 0.330070; batch adversarial loss: 0.677896
# epoch 12; iter: 0; batch classifier loss: 0.440217; batch adversarial loss: 0.657382
# epoch 13; iter: 0; batch classifier loss: 0.398155; batch adversarial loss: 0.669791
# epoch 14; iter: 0; batch classifier loss: 0.390560; batch adversarial loss: 0.657906
# epoch 15; iter: 0; batch classifier loss: 0.432139; batch adversarial loss: 0.661674
# epoch 16; iter: 0; batch classifier loss: 0.389998; batch adversarial loss: 0.676150
# epoch 17; iter: 0; batch classifier loss: 0.268795; batch adversarial loss: 0.668215
# epoch 18; iter: 0; batch classifier loss: 0.355421; batch adversarial loss: 0.595910
# epoch 19; iter: 0; batch classifier loss: 0.417694; batch adversarial loss: 0.581983
# epoch 20; iter: 0; batch classifier loss: 0.402928; batch adversarial loss: 0.669426
# epoch 21; iter: 0; batch classifier loss: 0.391440; batch adversarial loss: 0.660155
# epoch 22; iter: 0; batch classifier loss: 0.458265; batch adversarial loss: 0.671536
# epoch 23; iter: 0; batch classifier loss: 0.500760; batch adversarial loss: 0.658036
# epoch 24; iter: 0; batch classifier loss: 0.332777; batch adversarial loss: 0.606003
# epoch 25; iter: 0; batch classifier loss: 0.398138; batch adversarial loss: 0.701753
# epoch 26; iter: 0; batch classifier loss: 0.396653; batch adversarial loss: 0.681321
# epoch 27; iter: 0; batch classifier loss: 0.407627; batch adversarial loss: 0.713725
# epoch 28; iter: 0; batch classifier loss: 0.392467; batch adversarial loss: 0.612927
# epoch 29; iter: 0; batch classifier loss: 0.369352; batch adversarial loss: 0.584578
# epoch 30; iter: 0; batch classifier loss: 0.374073; batch adversarial loss: 0.683923
# epoch 31; iter: 0; batch classifier loss: 0.367171; batch adversarial loss: 0.712168
# epoch 32; iter: 0; batch classifier loss: 0.379269; batch adversarial loss: 0.593244
# epoch 33; iter: 0; batch classifier loss: 0.365115; batch adversarial loss: 0.545001
# epoch 34; iter: 0; batch classifier loss: 0.343551; batch adversarial loss: 0.660033
# epoch 35; iter: 0; batch classifier loss: 0.415911; batch adversarial loss: 0.663912
# epoch 36; iter: 0; batch classifier loss: 0.450301; batch adversarial loss: 0.668770
# epoch 37; iter: 0; batch classifier loss: 0.339968; batch adversarial loss: 0.659102
# epoch 38; iter: 0; batch classifier loss: 0.413156; batch adversarial loss: 0.694537
# epoch 39; iter: 0; batch classifier loss: 0.346943; batch adversarial loss: 0.644567
# epoch 40; iter: 0; batch classifier loss: 0.377037; batch adversarial loss: 0.678531
# epoch 41; iter: 0; batch classifier loss: 0.446021; batch adversarial loss: 0.562252
# epoch 42; iter: 0; batch classifier loss: 0.426020; batch adversarial loss: 0.625339
# epoch 43; iter: 0; batch classifier loss: 0.462724; batch adversarial loss: 0.751867
# epoch 44; iter: 0; batch classifier loss: 0.498241; batch adversarial loss: 0.629529
# epoch 45; iter: 0; batch classifier loss: 0.322768; batch adversarial loss: 0.655985
# epoch 46; iter: 0; batch classifier loss: 0.402835; batch adversarial loss: 0.653902
# epoch 47; iter: 0; batch classifier loss: 0.349910; batch adversarial loss: 0.579218
# epoch 48; iter: 0; batch classifier loss: 0.326839; batch adversarial loss: 0.758319
# epoch 49; iter: 0; batch classifier loss: 0.399855; batch adversarial loss: 0.640137
# Classification Report for Neural Network on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77      2246
#            1       0.83      0.79      0.81      2878
#
#     accuracy                           0.79      5124
#    macro avg       0.79      0.80      0.79      5124
# weighted avg       0.80      0.79      0.80      5124
#
# ROC-AUC Score for Neural Network on Base Dataset: Not Applicable
#
# Training and Evaluating LightGBM on Base dataset with Bias Mitigation...
# [LightGBM] [Info] Number of positive: 8783, number of negative: 8783
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015404 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3524
# [LightGBM] [Info] Number of data points in the train set: 17566, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.491205 -> initscore=-0.035185
# [LightGBM] [Info] Start training from score -0.035185
# Classification Report for LightGBM on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78      2246
#            1       0.84      0.80      0.82      2878
#
#     accuracy                           0.80      5124
#    macro avg       0.80      0.80      0.80      5124
# weighted avg       0.81      0.80      0.80      5124
#
# ROC-AUC Score for LightGBM on Base Dataset: 0.88
#
# Training and Evaluating XGBoost on Base dataset with Bias Mitigation...
# /opt/conda/lib/python3.10/site-packages/fairlearn/postprocessing/_interpolated_thresholder.py:154: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[9.98960863e-01 9.98960863e-01 9.98960863e-01 ... 9.98960863e-01
#  5.35412327e-05 5.35412327e-05]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   positive_probs[sensitive_feature_vector == a] = interpolated_predictions[
# Classification Report for XGBoost on Base Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76      2246
#            1       0.82      0.78      0.80      2878
#
#     accuracy                           0.78      5124
#    macro avg       0.78      0.78      0.78      5124
# weighted avg       0.78      0.78      0.78      5124
#
# ROC-AUC Score for XGBoost on Base Dataset: 0.87
#
# Processing Dataset: Variant I
#
# Training and Evaluating Logistic Regression on Variant I dataset with Bias Mitigation...
# Classification Report for Logistic Regression on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.69      0.82      0.75      2246
#            1       0.84      0.71      0.77      2878
#
#     accuracy                           0.76      5124
#    macro avg       0.76      0.77      0.76      5124
# weighted avg       0.77      0.76      0.76      5124
#
# ROC-AUC Score for Logistic Regression on Variant I Dataset: 0.85
#
# Training and Evaluating KNN on Variant I dataset with Bias Mitigation...
# Classification Report for KNN on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.56      0.83      0.67      2246
#            1       0.78      0.49      0.61      2878
#
#     accuracy                           0.64      5124
#    macro avg       0.67      0.66      0.64      5124
# weighted avg       0.69      0.64      0.63      5124
#
# ROC-AUC Score for KNN on Variant I Dataset: 0.80
#
# Training and Evaluating Random Forest on Variant I dataset with Bias Mitigation...
# Classification Report for Random Forest on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77      2246
#            1       0.82      0.81      0.81      2878
#
#     accuracy                           0.79      5124
#    macro avg       0.79      0.79      0.79      5124
# weighted avg       0.79      0.79      0.79      5124
#
# ROC-AUC Score for Random Forest on Variant I Dataset: 0.87
#
# Training and Evaluating Gaussian Naive Bayes on Variant I dataset with Bias Mitigation...
# Classification Report for Gaussian Naive Bayes on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73      2246
#            1       0.80      0.73      0.76      2878
#
#     accuracy                           0.75      5124
#    macro avg       0.74      0.75      0.74      5124
# weighted avg       0.75      0.75      0.75      5124
#
# ROC-AUC Score for Gaussian Naive Bayes on Variant I Dataset: 0.81
#
# Training and Evaluating Bernoulli Naive Bayes on Variant I dataset with Bias Mitigation...
# Classification Report for Bernoulli Naive Bayes on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74      2246
#            1       0.80      0.79      0.80      2878
#
#     accuracy                           0.77      5124
#    macro avg       0.77      0.77      0.77      5124
# weighted avg       0.77      0.77      0.77      5124
#
# ROC-AUC Score for Bernoulli Naive Bayes on Variant I Dataset: 0.84
#
# Training and Evaluating SVM on Variant I dataset with Bias Mitigation...
# Classification Report for SVM on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76      2246
#            1       0.82      0.81      0.81      2878
#
#     accuracy                           0.79      5124
#    macro avg       0.79      0.79      0.79      5124
# weighted avg       0.79      0.79      0.79      5124
#
# ROC-AUC Score for SVM on Variant I Dataset: 0.87
#
# Training and Evaluating Neural Network on Variant I dataset with Bias Mitigation...
# epoch 0; iter: 0; batch classifier loss: 0.717292; batch adversarial loss: 0.730850
# epoch 1; iter: 0; batch classifier loss: 0.443722; batch adversarial loss: 0.683156
# epoch 2; iter: 0; batch classifier loss: 0.508409; batch adversarial loss: 0.699637
# epoch 3; iter: 0; batch classifier loss: 0.571912; batch adversarial loss: 0.732998
# epoch 4; iter: 0; batch classifier loss: 0.531432; batch adversarial loss: 0.789775
# epoch 5; iter: 0; batch classifier loss: 0.443090; batch adversarial loss: 0.683701
# epoch 6; iter: 0; batch classifier loss: 0.502587; batch adversarial loss: 0.636741
# epoch 7; iter: 0; batch classifier loss: 0.420955; batch adversarial loss: 0.666558
# epoch 8; iter: 0; batch classifier loss: 0.471922; batch adversarial loss: 0.616175
# epoch 9; iter: 0; batch classifier loss: 0.411143; batch adversarial loss: 0.664354
# epoch 10; iter: 0; batch classifier loss: 0.574528; batch adversarial loss: 0.640236
# epoch 11; iter: 0; batch classifier loss: 0.366023; batch adversarial loss: 0.627788
# epoch 12; iter: 0; batch classifier loss: 0.432619; batch adversarial loss: 0.603232
# epoch 13; iter: 0; batch classifier loss: 0.475060; batch adversarial loss: 0.588063
# epoch 14; iter: 0; batch classifier loss: 0.491844; batch adversarial loss: 0.568072
# epoch 15; iter: 0; batch classifier loss: 0.394137; batch adversarial loss: 0.610510
# epoch 16; iter: 0; batch classifier loss: 0.424603; batch adversarial loss: 0.633052
# epoch 17; iter: 0; batch classifier loss: 0.455500; batch adversarial loss: 0.686616
# epoch 18; iter: 0; batch classifier loss: 0.358357; batch adversarial loss: 0.670200
# epoch 19; iter: 0; batch classifier loss: 0.372432; batch adversarial loss: 0.627303
# epoch 20; iter: 0; batch classifier loss: 0.482868; batch adversarial loss: 0.618802
# epoch 21; iter: 0; batch classifier loss: 0.392182; batch adversarial loss: 0.614712
# epoch 22; iter: 0; batch classifier loss: 0.425677; batch adversarial loss: 0.613964
# epoch 23; iter: 0; batch classifier loss: 0.367876; batch adversarial loss: 0.584814
# epoch 24; iter: 0; batch classifier loss: 0.501889; batch adversarial loss: 0.614681
# epoch 25; iter: 0; batch classifier loss: 0.388477; batch adversarial loss: 0.645214
# epoch 26; iter: 0; batch classifier loss: 0.431489; batch adversarial loss: 0.675652
# epoch 27; iter: 0; batch classifier loss: 0.298785; batch adversarial loss: 0.566350
# epoch 28; iter: 0; batch classifier loss: 0.422941; batch adversarial loss: 0.594322
# epoch 29; iter: 0; batch classifier loss: 0.445345; batch adversarial loss: 0.650656
# epoch 30; iter: 0; batch classifier loss: 0.432754; batch adversarial loss: 0.620070
# epoch 31; iter: 0; batch classifier loss: 0.398496; batch adversarial loss: 0.616891
# epoch 32; iter: 0; batch classifier loss: 0.345511; batch adversarial loss: 0.679362
# epoch 33; iter: 0; batch classifier loss: 0.358405; batch adversarial loss: 0.573517
# epoch 34; iter: 0; batch classifier loss: 0.484973; batch adversarial loss: 0.633919
# epoch 35; iter: 0; batch classifier loss: 0.485441; batch adversarial loss: 0.552242
# epoch 36; iter: 0; batch classifier loss: 0.357001; batch adversarial loss: 0.571515
# epoch 37; iter: 0; batch classifier loss: 0.376442; batch adversarial loss: 0.543273
# epoch 38; iter: 0; batch classifier loss: 0.388784; batch adversarial loss: 0.591484
# epoch 39; iter: 0; batch classifier loss: 0.469853; batch adversarial loss: 0.693975
# epoch 40; iter: 0; batch classifier loss: 0.447746; batch adversarial loss: 0.711675
# epoch 41; iter: 0; batch classifier loss: 0.388901; batch adversarial loss: 0.598123
# epoch 42; iter: 0; batch classifier loss: 0.451315; batch adversarial loss: 0.671169
# epoch 43; iter: 0; batch classifier loss: 0.434887; batch adversarial loss: 0.586313
# epoch 44; iter: 0; batch classifier loss: 0.437071; batch adversarial loss: 0.584062
# epoch 45; iter: 0; batch classifier loss: 0.429873; batch adversarial loss: 0.695958
# epoch 46; iter: 0; batch classifier loss: 0.401152; batch adversarial loss: 0.634246
# epoch 47; iter: 0; batch classifier loss: 0.379366; batch adversarial loss: 0.559472
# epoch 48; iter: 0; batch classifier loss: 0.399520; batch adversarial loss: 0.635892
# epoch 49; iter: 0; batch classifier loss: 0.350011; batch adversarial loss: 0.646582
# Classification Report for Neural Network on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76      2246
#            1       0.82      0.80      0.81      2878
#
#     accuracy                           0.79      5124
#    macro avg       0.78      0.79      0.78      5124
# weighted avg       0.79      0.79      0.79      5124
#
# ROC-AUC Score for Neural Network on Variant I Dataset: Not Applicable
#
# Training and Evaluating LightGBM on Variant I dataset with Bias Mitigation...
# [LightGBM] [Info] Number of positive: 8783, number of negative: 8783
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015209 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3515
# [LightGBM] [Info] Number of data points in the train set: 17566, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.484772 -> initscore=-0.060932
# [LightGBM] [Info] Start training from score -0.060932
# Classification Report for LightGBM on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79      2246
#            1       0.85      0.80      0.82      2878
#
#     accuracy                           0.81      5124
#    macro avg       0.80      0.81      0.80      5124
# weighted avg       0.81      0.81      0.81      5124
#
# ROC-AUC Score for LightGBM on Variant I Dataset: 0.89
#
# Training and Evaluating XGBoost on Variant I dataset with Bias Mitigation...
# /opt/conda/lib/python3.10/site-packages/fairlearn/postprocessing/_interpolated_thresholder.py:154: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.96121109 0.96121109 0.96121109 ... 0.96121109 0.00221417 0.00221417]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   positive_probs[sensitive_feature_vector == a] = interpolated_predictions[
# Classification Report for XGBoost on Variant I Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75      2246
#            1       0.82      0.76      0.79      2878
#
#     accuracy                           0.77      5124
#    macro avg       0.77      0.77      0.77      5124
# weighted avg       0.78      0.77      0.77      5124
#
# ROC-AUC Score for XGBoost on Variant I Dataset: 0.86
#
# Processing Dataset: Variant II
#
# Training and Evaluating Logistic Regression on Variant II dataset with Bias Mitigation...
# Classification Report for Logistic Regression on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77      2246
#            1       0.84      0.76      0.80      2878
#
#     accuracy                           0.78      5124
#    macro avg       0.78      0.79      0.78      5124
# weighted avg       0.79      0.78      0.79      5124
#
# ROC-AUC Score for Logistic Regression on Variant II Dataset: 0.87
#
# Training and Evaluating KNN on Variant II dataset with Bias Mitigation...
# Classification Report for KNN on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70      2246
#            1       0.79      0.67      0.73      2878
#
#     accuracy                           0.71      5124
#    macro avg       0.72      0.72      0.71      5124
# weighted avg       0.72      0.71      0.71      5124
#
# ROC-AUC Score for KNN on Variant II Dataset: 0.81
#
# Training and Evaluating Random Forest on Variant II dataset with Bias Mitigation...
# Classification Report for Random Forest on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78      2246
#            1       0.83      0.80      0.82      2878
#
#     accuracy                           0.80      5124
#    macro avg       0.80      0.80      0.80      5124
# weighted avg       0.80      0.80      0.80      5124
#
# ROC-AUC Score for Random Forest on Variant II Dataset: 0.88
#
# Training and Evaluating Gaussian Naive Bayes on Variant II dataset with Bias Mitigation...
# Classification Report for Gaussian Naive Bayes on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.72      0.77      0.74      2246
#            1       0.81      0.77      0.79      2878
#
#     accuracy                           0.77      5124
#    macro avg       0.76      0.77      0.76      5124
# weighted avg       0.77      0.77      0.77      5124
#
# ROC-AUC Score for Gaussian Naive Bayes on Variant II Dataset: 0.83
#
# Training and Evaluating Bernoulli Naive Bayes on Variant II dataset with Bias Mitigation...
# Classification Report for Bernoulli Naive Bayes on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75      2246
#            1       0.81      0.80      0.80      2878
#
#     accuracy                           0.78      5124
#    macro avg       0.78      0.78      0.78      5124
# weighted avg       0.78      0.78      0.78      5124
#
# ROC-AUC Score for Bernoulli Naive Bayes on Variant II Dataset: 0.85
#
# Training and Evaluating SVM on Variant II dataset with Bias Mitigation...
# Classification Report for SVM on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76      2246
#            1       0.81      0.84      0.82      2878
#
#     accuracy                           0.80      5124
#    macro avg       0.79      0.79      0.79      5124
# weighted avg       0.80      0.80      0.80      5124
#
# ROC-AUC Score for SVM on Variant II Dataset: 0.87
#
# Training and Evaluating Neural Network on Variant II dataset with Bias Mitigation...
# epoch 0; iter: 0; batch classifier loss: 0.754984; batch adversarial loss: 0.691703
# epoch 1; iter: 0; batch classifier loss: 0.520952; batch adversarial loss: 0.682706
# epoch 2; iter: 0; batch classifier loss: 0.423978; batch adversarial loss: 0.680069
# epoch 3; iter: 0; batch classifier loss: 0.379586; batch adversarial loss: 0.679085
# epoch 4; iter: 0; batch classifier loss: 0.453942; batch adversarial loss: 0.599174
# epoch 5; iter: 0; batch classifier loss: 0.388893; batch adversarial loss: 0.729925
# epoch 6; iter: 0; batch classifier loss: 0.378526; batch adversarial loss: 0.644173
# epoch 7; iter: 0; batch classifier loss: 0.460848; batch adversarial loss: 0.738256
# epoch 8; iter: 0; batch classifier loss: 0.400960; batch adversarial loss: 0.652340
# epoch 9; iter: 0; batch classifier loss: 0.370539; batch adversarial loss: 0.735267
# epoch 10; iter: 0; batch classifier loss: 0.455383; batch adversarial loss: 0.700439
# epoch 11; iter: 0; batch classifier loss: 0.396313; batch adversarial loss: 0.636552
# epoch 12; iter: 0; batch classifier loss: 0.310314; batch adversarial loss: 0.683485
# epoch 13; iter: 0; batch classifier loss: 0.378467; batch adversarial loss: 0.636975
# epoch 14; iter: 0; batch classifier loss: 0.340105; batch adversarial loss: 0.675985
# epoch 15; iter: 0; batch classifier loss: 0.418882; batch adversarial loss: 0.622035
# epoch 16; iter: 0; batch classifier loss: 0.333163; batch adversarial loss: 0.709087
# epoch 17; iter: 0; batch classifier loss: 0.506007; batch adversarial loss: 0.659852
# epoch 18; iter: 0; batch classifier loss: 0.368647; batch adversarial loss: 0.624973
# epoch 19; iter: 0; batch classifier loss: 0.376833; batch adversarial loss: 0.682036
# epoch 20; iter: 0; batch classifier loss: 0.374140; batch adversarial loss: 0.655757
# epoch 21; iter: 0; batch classifier loss: 0.423956; batch adversarial loss: 0.713251
# epoch 22; iter: 0; batch classifier loss: 0.397700; batch adversarial loss: 0.712045
# epoch 23; iter: 0; batch classifier loss: 0.370748; batch adversarial loss: 0.654345
# epoch 24; iter: 0; batch classifier loss: 0.395200; batch adversarial loss: 0.692232
# epoch 25; iter: 0; batch classifier loss: 0.420970; batch adversarial loss: 0.549512
# epoch 26; iter: 0; batch classifier loss: 0.361064; batch adversarial loss: 0.689026
# epoch 27; iter: 0; batch classifier loss: 0.343457; batch adversarial loss: 0.669464
# epoch 28; iter: 0; batch classifier loss: 0.361836; batch adversarial loss: 0.610161
# epoch 29; iter: 0; batch classifier loss: 0.352788; batch adversarial loss: 0.638163
# epoch 30; iter: 0; batch classifier loss: 0.408400; batch adversarial loss: 0.695332
# epoch 31; iter: 0; batch classifier loss: 0.311486; batch adversarial loss: 0.700058
# epoch 32; iter: 0; batch classifier loss: 0.339623; batch adversarial loss: 0.629629
# epoch 33; iter: 0; batch classifier loss: 0.417862; batch adversarial loss: 0.717048
# epoch 34; iter: 0; batch classifier loss: 0.406728; batch adversarial loss: 0.680124
# epoch 35; iter: 0; batch classifier loss: 0.442161; batch adversarial loss: 0.714175
# epoch 36; iter: 0; batch classifier loss: 0.453311; batch adversarial loss: 0.681956
# epoch 37; iter: 0; batch classifier loss: 0.329592; batch adversarial loss: 0.634040
# epoch 38; iter: 0; batch classifier loss: 0.315977; batch adversarial loss: 0.768095
# epoch 39; iter: 0; batch classifier loss: 0.297430; batch adversarial loss: 0.725784
# epoch 40; iter: 0; batch classifier loss: 0.383306; batch adversarial loss: 0.573466
# epoch 41; iter: 0; batch classifier loss: 0.398152; batch adversarial loss: 0.710466
# epoch 42; iter: 0; batch classifier loss: 0.380681; batch adversarial loss: 0.684399
# epoch 43; iter: 0; batch classifier loss: 0.353886; batch adversarial loss: 0.697405
# epoch 44; iter: 0; batch classifier loss: 0.380983; batch adversarial loss: 0.727534
# epoch 45; iter: 0; batch classifier loss: 0.352182; batch adversarial loss: 0.641975
# epoch 46; iter: 0; batch classifier loss: 0.340074; batch adversarial loss: 0.657897
# epoch 47; iter: 0; batch classifier loss: 0.353263; batch adversarial loss: 0.620543
# epoch 48; iter: 0; batch classifier loss: 0.342404; batch adversarial loss: 0.713208
# epoch 49; iter: 0; batch classifier loss: 0.393472; batch adversarial loss: 0.556910
# Classification Report for Neural Network on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77      2246
#            1       0.83      0.79      0.81      2878
#
#     accuracy                           0.79      5124
#    macro avg       0.79      0.79      0.79      5124
# weighted avg       0.80      0.79      0.80      5124
#
# ROC-AUC Score for Neural Network on Variant II Dataset: Not Applicable
#
# Training and Evaluating LightGBM on Variant II dataset with Bias Mitigation...
# [LightGBM] [Info] Number of positive: 8783, number of negative: 8783
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015861 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3520
# [LightGBM] [Info] Number of data points in the train set: 17566, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501195 -> initscore=0.004782
# [LightGBM] [Info] Start training from score 0.004782
# Classification Report for LightGBM on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78      2246
#            1       0.83      0.83      0.83      2878
#
#     accuracy                           0.81      5124
#    macro avg       0.81      0.81      0.81      5124
# weighted avg       0.81      0.81      0.81      5124
#
# ROC-AUC Score for LightGBM on Variant II Dataset: 0.89
#
# Training and Evaluating XGBoost on Variant II dataset with Bias Mitigation...
# /opt/conda/lib/python3.10/site-packages/fairlearn/postprocessing/_interpolated_thresholder.py:154: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.98228424 0.98228424 0.00099148 ... 0.98228424 0.98228424 0.00099148]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   positive_probs[sensitive_feature_vector == a] = interpolated_predictions[
# Classification Report for XGBoost on Variant II Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      2246
#            1       0.82      0.79      0.81      2878
#
#     accuracy                           0.78      5124
#    macro avg       0.78      0.78      0.78      5124
# weighted avg       0.79      0.78      0.78      5124
#
# ROC-AUC Score for XGBoost on Variant II Dataset: 0.88
#
# Processing Dataset: Variant III
#
# Training and Evaluating Logistic Regression on Variant III dataset with Bias Mitigation...
# Classification Report for Logistic Regression on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      2615
#            1       0.85      0.80      0.82      2652
#
#     accuracy                           0.83      5267
#    macro avg       0.83      0.83      0.83      5267
# weighted avg       0.83      0.83      0.83      5267
#
# ROC-AUC Score for Logistic Regression on Variant III Dataset: 0.91
#
# Training and Evaluating KNN on Variant III dataset with Bias Mitigation...
# Classification Report for KNN on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77      2615
#            1       0.78      0.76      0.77      2652
#
#     accuracy                           0.77      5267
#    macro avg       0.77      0.77      0.77      5267
# weighted avg       0.77      0.77      0.77      5267
#
# ROC-AUC Score for KNN on Variant III Dataset: 0.88
#
# Training and Evaluating Random Forest on Variant III dataset with Bias Mitigation...
# Classification Report for Random Forest on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      2615
#            1       0.86      0.86      0.86      2652
#
#     accuracy                           0.86      5267
#    macro avg       0.86      0.86      0.86      5267
# weighted avg       0.86      0.86      0.86      5267
#
# ROC-AUC Score for Random Forest on Variant III Dataset: 0.94
#
# Training and Evaluating Gaussian Naive Bayes on Variant III dataset with Bias Mitigation...
# Classification Report for Gaussian Naive Bayes on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      2615
#            1       0.84      0.78      0.81      2652
#
#     accuracy                           0.81      5267
#    macro avg       0.82      0.81      0.81      5267
# weighted avg       0.82      0.81      0.81      5267
#
# ROC-AUC Score for Gaussian Naive Bayes on Variant III Dataset: 0.88
#
# Training and Evaluating Bernoulli Naive Bayes on Variant III dataset with Bias Mitigation...
# Classification Report for Bernoulli Naive Bayes on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      2615
#            1       0.79      0.82      0.81      2652
#
#     accuracy                           0.80      5267
#    macro avg       0.80      0.80      0.80      5267
# weighted avg       0.80      0.80      0.80      5267
#
# ROC-AUC Score for Bernoulli Naive Bayes on Variant III Dataset: 0.88
#
# Training and Evaluating SVM on Variant III dataset with Bias Mitigation...
# Classification Report for SVM on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      2615
#            1       0.85      0.86      0.86      2652
#
#     accuracy                           0.86      5267
#    macro avg       0.86      0.86      0.86      5267
# weighted avg       0.86      0.86      0.86      5267
#
# ROC-AUC Score for SVM on Variant III Dataset: 0.93
#
# Training and Evaluating Neural Network on Variant III dataset with Bias Mitigation...
# epoch 0; iter: 0; batch classifier loss: 0.784076; batch adversarial loss: 0.692788
# epoch 1; iter: 0; batch classifier loss: 0.476041; batch adversarial loss: 0.764795
# epoch 2; iter: 0; batch classifier loss: 0.412317; batch adversarial loss: 0.735223
# epoch 3; iter: 0; batch classifier loss: 0.297658; batch adversarial loss: 0.669173
# epoch 4; iter: 0; batch classifier loss: 0.364346; batch adversarial loss: 0.652441
# epoch 5; iter: 0; batch classifier loss: 0.236709; batch adversarial loss: 0.671504
# epoch 6; iter: 0; batch classifier loss: 0.304181; batch adversarial loss: 0.694885
# epoch 7; iter: 0; batch classifier loss: 0.333556; batch adversarial loss: 0.649899
# epoch 8; iter: 0; batch classifier loss: 0.303360; batch adversarial loss: 0.646836
# epoch 9; iter: 0; batch classifier loss: 0.220515; batch adversarial loss: 0.654543
# epoch 10; iter: 0; batch classifier loss: 0.331115; batch adversarial loss: 0.692585
# epoch 11; iter: 0; batch classifier loss: 0.305775; batch adversarial loss: 0.547515
# epoch 12; iter: 0; batch classifier loss: 0.313188; batch adversarial loss: 0.585192
# epoch 13; iter: 0; batch classifier loss: 0.258518; batch adversarial loss: 0.544145
# epoch 14; iter: 0; batch classifier loss: 0.268463; batch adversarial loss: 0.695055
# epoch 15; iter: 0; batch classifier loss: 0.222163; batch adversarial loss: 0.484551
# epoch 16; iter: 0; batch classifier loss: 0.250519; batch adversarial loss: 0.693274
# epoch 17; iter: 0; batch classifier loss: 0.277702; batch adversarial loss: 0.499375
# epoch 18; iter: 0; batch classifier loss: 0.241220; batch adversarial loss: 0.468891
# epoch 19; iter: 0; batch classifier loss: 0.217677; batch adversarial loss: 0.547552
# epoch 20; iter: 0; batch classifier loss: 0.274981; batch adversarial loss: 0.477436
# epoch 21; iter: 0; batch classifier loss: 0.302981; batch adversarial loss: 0.582041
# epoch 22; iter: 0; batch classifier loss: 0.283611; batch adversarial loss: 0.703601
# epoch 23; iter: 0; batch classifier loss: 0.287057; batch adversarial loss: 0.615314
# epoch 24; iter: 0; batch classifier loss: 0.242584; batch adversarial loss: 0.724256
# epoch 25; iter: 0; batch classifier loss: 0.262632; batch adversarial loss: 0.620467
# epoch 26; iter: 0; batch classifier loss: 0.286344; batch adversarial loss: 0.761750
# epoch 27; iter: 0; batch classifier loss: 0.232681; batch adversarial loss: 0.594766
# epoch 28; iter: 0; batch classifier loss: 0.227952; batch adversarial loss: 0.713656
# epoch 29; iter: 0; batch classifier loss: 0.222821; batch adversarial loss: 0.756709
# epoch 30; iter: 0; batch classifier loss: 0.322852; batch adversarial loss: 0.606906
# epoch 31; iter: 0; batch classifier loss: 0.262234; batch adversarial loss: 0.559639
# epoch 32; iter: 0; batch classifier loss: 0.241227; batch adversarial loss: 0.666954
# epoch 33; iter: 0; batch classifier loss: 0.268392; batch adversarial loss: 0.559378
# epoch 34; iter: 0; batch classifier loss: 0.230144; batch adversarial loss: 0.633882
# epoch 35; iter: 0; batch classifier loss: 0.349613; batch adversarial loss: 0.659106
# epoch 36; iter: 0; batch classifier loss: 0.306642; batch adversarial loss: 0.582552
# epoch 37; iter: 0; batch classifier loss: 0.257297; batch adversarial loss: 0.712485
# epoch 38; iter: 0; batch classifier loss: 0.295393; batch adversarial loss: 0.539723
# epoch 39; iter: 0; batch classifier loss: 0.268959; batch adversarial loss: 0.540347
# epoch 40; iter: 0; batch classifier loss: 0.320069; batch adversarial loss: 0.636885
# epoch 41; iter: 0; batch classifier loss: 0.226157; batch adversarial loss: 0.629060
# epoch 42; iter: 0; batch classifier loss: 0.210062; batch adversarial loss: 0.514627
# epoch 43; iter: 0; batch classifier loss: 0.138458; batch adversarial loss: 0.523976
# epoch 44; iter: 0; batch classifier loss: 0.186350; batch adversarial loss: 0.673445
# epoch 45; iter: 0; batch classifier loss: 0.286210; batch adversarial loss: 0.511122
# epoch 46; iter: 0; batch classifier loss: 0.217790; batch adversarial loss: 0.574968
# epoch 47; iter: 0; batch classifier loss: 0.195648; batch adversarial loss: 0.645942
# epoch 48; iter: 0; batch classifier loss: 0.266006; batch adversarial loss: 0.672314
# epoch 49; iter: 0; batch classifier loss: 0.272934; batch adversarial loss: 0.800176
# Classification Report for Neural Network on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86      2615
#            1       0.87      0.85      0.86      2652
#
#     accuracy                           0.86      5267
#    macro avg       0.86      0.86      0.86      5267
# weighted avg       0.86      0.86      0.86      5267
#
# ROC-AUC Score for Neural Network on Variant III Dataset: Not Applicable
#
# Training and Evaluating LightGBM on Variant III dataset with Bias Mitigation...
# [LightGBM] [Info] Number of positive: 8415, number of negative: 8415
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015571 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3701
# [LightGBM] [Info] Number of data points in the train set: 16830, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.485146 -> initscore=-0.059435
# [LightGBM] [Info] Start training from score -0.059435
# Classification Report for LightGBM on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87      2615
#            1       0.88      0.87      0.87      2652
#
#     accuracy                           0.87      5267
#    macro avg       0.87      0.87      0.87      5267
# weighted avg       0.87      0.87      0.87      5267
#
# ROC-AUC Score for LightGBM on Variant III Dataset: 0.95
#
# Training and Evaluating XGBoost on Variant III dataset with Bias Mitigation...
# /opt/conda/lib/python3.10/site-packages/fairlearn/postprocessing/_interpolated_thresholder.py:154: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.14882739e-04 9.89470746e-01 9.89470746e-01 ... 9.89470746e-01
#  9.89470746e-01 2.14882739e-04]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   positive_probs[sensitive_feature_vector == a] = interpolated_predictions[
# Classification Report for XGBoost on Variant III Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      2615
#            1       0.86      0.87      0.86      2652
#
#     accuracy                           0.86      5267
#    macro avg       0.86      0.86      0.86      5267
# weighted avg       0.86      0.86      0.86      5267
#
# ROC-AUC Score for XGBoost on Variant III Dataset: 0.94
#
# Processing Dataset: Variant IV
#
# Training and Evaluating Logistic Regression on Variant IV dataset with Bias Mitigation...
# Classification Report for Logistic Regression on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75      2615
#            1       0.77      0.67      0.72      2652
#
#     accuracy                           0.73      5267
#    macro avg       0.74      0.73      0.73      5267
# weighted avg       0.74      0.73      0.73      5267
#
# ROC-AUC Score for Logistic Regression on Variant IV Dataset: 0.81
#
# Training and Evaluating KNN on Variant IV dataset with Bias Mitigation...
# Classification Report for KNN on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67      2615
#            1       0.67      0.64      0.66      2652
#
#     accuracy                           0.66      5267
#    macro avg       0.66      0.66      0.66      5267
# weighted avg       0.66      0.66      0.66      5267
#
# ROC-AUC Score for KNN on Variant IV Dataset: 0.77
#
# Training and Evaluating Random Forest on Variant IV dataset with Bias Mitigation...
# Classification Report for Random Forest on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.73      0.79      0.76      2615
#            1       0.77      0.70      0.74      2652
#
#     accuracy                           0.75      5267
#    macro avg       0.75      0.75      0.75      5267
# weighted avg       0.75      0.75      0.75      5267
#
# ROC-AUC Score for Random Forest on Variant IV Dataset: 0.82
#
# Training and Evaluating Gaussian Naive Bayes on Variant IV dataset with Bias Mitigation...
# Classification Report for Gaussian Naive Bayes on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.68      0.77      0.72      2615
#            1       0.74      0.65      0.69      2652
#
#     accuracy                           0.71      5267
#    macro avg       0.71      0.71      0.71      5267
# weighted avg       0.71      0.71      0.71      5267
#
# ROC-AUC Score for Gaussian Naive Bayes on Variant IV Dataset: 0.77
#
# Training and Evaluating Bernoulli Naive Bayes on Variant IV dataset with Bias Mitigation...
# Classification Report for Bernoulli Naive Bayes on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71      2615
#            1       0.72      0.70      0.71      2652
#
#     accuracy                           0.71      5267
#    macro avg       0.71      0.71      0.71      5267
# weighted avg       0.71      0.71      0.71      5267
#
# ROC-AUC Score for Bernoulli Naive Bayes on Variant IV Dataset: 0.78
#
# Training and Evaluating SVM on Variant IV dataset with Bias Mitigation...
# Classification Report for SVM on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75      2615
#            1       0.76      0.75      0.75      2652
#
#     accuracy                           0.75      5267
#    macro avg       0.75      0.75      0.75      5267
# weighted avg       0.75      0.75      0.75      5267
#
# ROC-AUC Score for SVM on Variant IV Dataset: 0.83
#
# Training and Evaluating Neural Network on Variant IV dataset with Bias Mitigation...
# epoch 0; iter: 0; batch classifier loss: 0.679551; batch adversarial loss: 0.710860
# epoch 1; iter: 0; batch classifier loss: 0.383932; batch adversarial loss: 0.721310
# epoch 2; iter: 0; batch classifier loss: 0.476582; batch adversarial loss: 0.714090
# epoch 3; iter: 0; batch classifier loss: 0.422997; batch adversarial loss: 0.703172
# epoch 4; iter: 0; batch classifier loss: 0.386624; batch adversarial loss: 0.726240
# epoch 5; iter: 0; batch classifier loss: 0.364496; batch adversarial loss: 0.695821
# epoch 6; iter: 0; batch classifier loss: 0.367643; batch adversarial loss: 0.644136
# epoch 7; iter: 0; batch classifier loss: 0.401327; batch adversarial loss: 0.698196
# epoch 8; iter: 0; batch classifier loss: 0.455461; batch adversarial loss: 0.700328
# epoch 9; iter: 0; batch classifier loss: 0.441153; batch adversarial loss: 0.698267
# epoch 10; iter: 0; batch classifier loss: 0.372228; batch adversarial loss: 0.684797
# epoch 11; iter: 0; batch classifier loss: 0.355447; batch adversarial loss: 0.547360
# epoch 12; iter: 0; batch classifier loss: 0.378307; batch adversarial loss: 0.675767
# epoch 13; iter: 0; batch classifier loss: 0.412487; batch adversarial loss: 0.652250
# epoch 14; iter: 0; batch classifier loss: 0.462653; batch adversarial loss: 0.648019
# epoch 15; iter: 0; batch classifier loss: 0.434200; batch adversarial loss: 0.737577
# epoch 16; iter: 0; batch classifier loss: 0.393359; batch adversarial loss: 0.628568
# epoch 17; iter: 0; batch classifier loss: 0.326953; batch adversarial loss: 0.713136
# epoch 18; iter: 0; batch classifier loss: 0.456846; batch adversarial loss: 0.730263
# epoch 19; iter: 0; batch classifier loss: 0.330291; batch adversarial loss: 0.651675
# epoch 20; iter: 0; batch classifier loss: 0.333008; batch adversarial loss: 0.721363
# epoch 21; iter: 0; batch classifier loss: 0.347879; batch adversarial loss: 0.614320
# epoch 22; iter: 0; batch classifier loss: 0.414521; batch adversarial loss: 0.697416
# epoch 23; iter: 0; batch classifier loss: 0.327887; batch adversarial loss: 0.663652
# epoch 24; iter: 0; batch classifier loss: 0.461201; batch adversarial loss: 0.509149
# epoch 25; iter: 0; batch classifier loss: 0.306299; batch adversarial loss: 0.663887
# epoch 26; iter: 0; batch classifier loss: 0.391892; batch adversarial loss: 0.707948
# epoch 27; iter: 0; batch classifier loss: 0.415153; batch adversarial loss: 0.517188
# epoch 28; iter: 0; batch classifier loss: 0.446392; batch adversarial loss: 0.673335
# epoch 29; iter: 0; batch classifier loss: 0.329187; batch adversarial loss: 0.677595
# epoch 30; iter: 0; batch classifier loss: 0.297624; batch adversarial loss: 0.635981
# epoch 31; iter: 0; batch classifier loss: 0.421548; batch adversarial loss: 0.700634
# epoch 32; iter: 0; batch classifier loss: 0.280256; batch adversarial loss: 0.616484
# epoch 33; iter: 0; batch classifier loss: 0.282273; batch adversarial loss: 0.755030
# epoch 34; iter: 0; batch classifier loss: 0.387394; batch adversarial loss: 0.568899
# epoch 35; iter: 0; batch classifier loss: 0.349812; batch adversarial loss: 0.661577
# epoch 36; iter: 0; batch classifier loss: 0.288510; batch adversarial loss: 0.545125
# epoch 37; iter: 0; batch classifier loss: 0.328719; batch adversarial loss: 0.549699
# epoch 38; iter: 0; batch classifier loss: 0.300395; batch adversarial loss: 0.641661
# epoch 39; iter: 0; batch classifier loss: 0.337538; batch adversarial loss: 0.709199
# epoch 40; iter: 0; batch classifier loss: 0.362552; batch adversarial loss: 0.597228
# epoch 41; iter: 0; batch classifier loss: 0.396707; batch adversarial loss: 0.601956
# epoch 42; iter: 0; batch classifier loss: 0.325468; batch adversarial loss: 0.647292
# epoch 43; iter: 0; batch classifier loss: 0.463716; batch adversarial loss: 0.555548
# epoch 44; iter: 0; batch classifier loss: 0.463061; batch adversarial loss: 0.766392
# epoch 45; iter: 0; batch classifier loss: 0.366299; batch adversarial loss: 0.735706
# epoch 46; iter: 0; batch classifier loss: 0.369165; batch adversarial loss: 0.620398
# epoch 47; iter: 0; batch classifier loss: 0.499012; batch adversarial loss: 0.664415
# epoch 48; iter: 0; batch classifier loss: 0.427153; batch adversarial loss: 0.670582
# epoch 49; iter: 0; batch classifier loss: 0.448602; batch adversarial loss: 0.631179
# Classification Report for Neural Network on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75      2615
#            1       0.77      0.70      0.74      2652
#
#     accuracy                           0.74      5267
#    macro avg       0.75      0.75      0.74      5267
# weighted avg       0.75      0.74      0.74      5267
#
# ROC-AUC Score for Neural Network on Variant IV Dataset: Not Applicable
#
# Training and Evaluating LightGBM on Variant IV dataset with Bias Mitigation...
# [LightGBM] [Info] Number of positive: 8415, number of negative: 8415
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013652 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3190
# [LightGBM] [Info] Number of data points in the train set: 16830, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499228 -> initscore=-0.003090
# [LightGBM] [Info] Start training from score -0.003090
# Classification Report for LightGBM on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77      2615
#            1       0.78      0.74      0.76      2652
#
#     accuracy                           0.76      5267
#    macro avg       0.76      0.76      0.76      5267
# weighted avg       0.76      0.76      0.76      5267
#
# ROC-AUC Score for LightGBM on Variant IV Dataset: 0.84
#
# Training and Evaluating XGBoost on Variant IV dataset with Bias Mitigation...
# /opt/conda/lib/python3.10/site-packages/fairlearn/postprocessing/_interpolated_thresholder.py:154: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[5.23934752e-06 9.99863635e-01 9.99863635e-01 ... 5.23934752e-06
#  5.23934752e-06 5.23934752e-06]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   positive_probs[sensitive_feature_vector == a] = interpolated_predictions[
# Classification Report for XGBoost on Variant IV Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76      2615
#            1       0.77      0.72      0.74      2652
#
#     accuracy                           0.75      5267
#    macro avg       0.75      0.75      0.75      5267
# weighted avg       0.75      0.75      0.75      5267
#
# ROC-AUC Score for XGBoost on Variant IV Dataset: 0.83
#
# Processing Dataset: Variant V
#
# Training and Evaluating Logistic Regression on Variant V dataset with Bias Mitigation...
# Classification Report for Logistic Regression on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.65      0.85      0.73      2615
#            1       0.79      0.54      0.64      2652
#
#     accuracy                           0.69      5267
#    macro avg       0.72      0.69      0.69      5267
# weighted avg       0.72      0.69      0.69      5267
#
# ROC-AUC Score for Logistic Regression on Variant V Dataset: 0.78
#
# Training and Evaluating KNN on Variant V dataset with Bias Mitigation...
# Classification Report for KNN on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70      2615
#            1       0.71      0.60      0.65      2652
#
#     accuracy                           0.68      5267
#    macro avg       0.68      0.68      0.67      5267
# weighted avg       0.68      0.68      0.67      5267
#
# ROC-AUC Score for KNN on Variant V Dataset: 0.77
#
# Training and Evaluating Random Forest on Variant V dataset with Bias Mitigation...
# Classification Report for Random Forest on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.63      0.88      0.73      2615
#            1       0.80      0.48      0.60      2652
#
#     accuracy                           0.68      5267
#    macro avg       0.71      0.68      0.67      5267
# weighted avg       0.71      0.68      0.67      5267
#
# ROC-AUC Score for Random Forest on Variant V Dataset: 0.78
#
# Training and Evaluating Gaussian Naive Bayes on Variant V dataset with Bias Mitigation...
# Classification Report for Gaussian Naive Bayes on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.66      0.84      0.74      2615
#            1       0.78      0.57      0.66      2652
#
#     accuracy                           0.70      5267
#    macro avg       0.72      0.70      0.70      5267
# weighted avg       0.72      0.70      0.70      5267
#
# ROC-AUC Score for Gaussian Naive Bayes on Variant V Dataset: 0.78
#
# Training and Evaluating Bernoulli Naive Bayes on Variant V dataset with Bias Mitigation...
# Classification Report for Bernoulli Naive Bayes on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75      2615
#            1       0.76      0.70      0.73      2652
#
#     accuracy                           0.74      5267
#    macro avg       0.74      0.74      0.74      5267
# weighted avg       0.74      0.74      0.74      5267
#
# ROC-AUC Score for Bernoulli Naive Bayes on Variant V Dataset: 0.81
#
# Training and Evaluating SVM on Variant V dataset with Bias Mitigation...
# Classification Report for SVM on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.66      0.85      0.74      2615
#            1       0.79      0.56      0.66      2652
#
#     accuracy                           0.70      5267
#    macro avg       0.72      0.70      0.70      5267
# weighted avg       0.72      0.70      0.70      5267
#
# ROC-AUC Score for SVM on Variant V Dataset: 0.78
#
# Training and Evaluating Neural Network on Variant V dataset with Bias Mitigation...
# epoch 0; iter: 0; batch classifier loss: 0.726557; batch adversarial loss: 0.742948
# epoch 1; iter: 0; batch classifier loss: 0.397802; batch adversarial loss: 0.751758
# epoch 2; iter: 0; batch classifier loss: 0.308194; batch adversarial loss: 0.694532
# epoch 3; iter: 0; batch classifier loss: 0.264959; batch adversarial loss: 0.702874
# epoch 4; iter: 0; batch classifier loss: 0.315023; batch adversarial loss: 0.675727
# epoch 5; iter: 0; batch classifier loss: 0.282410; batch adversarial loss: 0.676034
# epoch 6; iter: 0; batch classifier loss: 0.380959; batch adversarial loss: 0.652873
# epoch 7; iter: 0; batch classifier loss: 0.421626; batch adversarial loss: 0.607714
# epoch 8; iter: 0; batch classifier loss: 0.281029; batch adversarial loss: 0.712253
# epoch 9; iter: 0; batch classifier loss: 0.318616; batch adversarial loss: 0.607544
# epoch 10; iter: 0; batch classifier loss: 0.244935; batch adversarial loss: 0.608326
# epoch 11; iter: 0; batch classifier loss: 0.209361; batch adversarial loss: 0.565611
# epoch 12; iter: 0; batch classifier loss: 0.379902; batch adversarial loss: 0.589648
# epoch 13; iter: 0; batch classifier loss: 0.333983; batch adversarial loss: 0.666729
# epoch 14; iter: 0; batch classifier loss: 0.262874; batch adversarial loss: 0.581497
# epoch 15; iter: 0; batch classifier loss: 0.262527; batch adversarial loss: 0.623291
# epoch 16; iter: 0; batch classifier loss: 0.230692; batch adversarial loss: 0.613989
# epoch 17; iter: 0; batch classifier loss: 0.291787; batch adversarial loss: 0.583431
# epoch 18; iter: 0; batch classifier loss: 0.199589; batch adversarial loss: 0.624416
# epoch 19; iter: 0; batch classifier loss: 0.272531; batch adversarial loss: 0.677860
# epoch 20; iter: 0; batch classifier loss: 0.271474; batch adversarial loss: 0.665833
# epoch 21; iter: 0; batch classifier loss: 0.258859; batch adversarial loss: 0.749371
# epoch 22; iter: 0; batch classifier loss: 0.175293; batch adversarial loss: 0.557203
# epoch 23; iter: 0; batch classifier loss: 0.286065; batch adversarial loss: 0.683432
# epoch 24; iter: 0; batch classifier loss: 0.275592; batch adversarial loss: 0.659902
# epoch 25; iter: 0; batch classifier loss: 0.241120; batch adversarial loss: 0.604162
# epoch 26; iter: 0; batch classifier loss: 0.154165; batch adversarial loss: 0.614889
# epoch 27; iter: 0; batch classifier loss: 0.240667; batch adversarial loss: 0.651164
# epoch 28; iter: 0; batch classifier loss: 0.316899; batch adversarial loss: 0.428207
# epoch 29; iter: 0; batch classifier loss: 0.280636; batch adversarial loss: 0.576040
# epoch 30; iter: 0; batch classifier loss: 0.235461; batch adversarial loss: 0.731820
# epoch 31; iter: 0; batch classifier loss: 0.224034; batch adversarial loss: 0.568813
# epoch 32; iter: 0; batch classifier loss: 0.216033; batch adversarial loss: 0.620374
# epoch 33; iter: 0; batch classifier loss: 0.163631; batch adversarial loss: 0.773612
# epoch 34; iter: 0; batch classifier loss: 0.276271; batch adversarial loss: 0.594126
# epoch 35; iter: 0; batch classifier loss: 0.208957; batch adversarial loss: 0.650073
# epoch 36; iter: 0; batch classifier loss: 0.182757; batch adversarial loss: 0.649065
# epoch 37; iter: 0; batch classifier loss: 0.240942; batch adversarial loss: 0.523996
# epoch 38; iter: 0; batch classifier loss: 0.213770; batch adversarial loss: 0.733855
# epoch 39; iter: 0; batch classifier loss: 0.209765; batch adversarial loss: 0.639286
# epoch 40; iter: 0; batch classifier loss: 0.222074; batch adversarial loss: 0.688641
# epoch 41; iter: 0; batch classifier loss: 0.233905; batch adversarial loss: 0.703105
# epoch 42; iter: 0; batch classifier loss: 0.194697; batch adversarial loss: 0.567358
# epoch 43; iter: 0; batch classifier loss: 0.171657; batch adversarial loss: 0.565543
# epoch 44; iter: 0; batch classifier loss: 0.166952; batch adversarial loss: 0.621751
# epoch 45; iter: 0; batch classifier loss: 0.276143; batch adversarial loss: 0.743380
# epoch 46; iter: 0; batch classifier loss: 0.213229; batch adversarial loss: 0.552784
# epoch 47; iter: 0; batch classifier loss: 0.236811; batch adversarial loss: 0.603288
# epoch 48; iter: 0; batch classifier loss: 0.220897; batch adversarial loss: 0.581318
# epoch 49; iter: 0; batch classifier loss: 0.284680; batch adversarial loss: 0.518360
# Classification Report for Neural Network on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.73      2615
#            1       0.79      0.51      0.62      2652
#
#     accuracy                           0.68      5267
#    macro avg       0.71      0.69      0.68      5267
# weighted avg       0.71      0.68      0.68      5267
#
# ROC-AUC Score for Neural Network on Variant V Dataset: Not Applicable
#
# Training and Evaluating LightGBM on Variant V dataset with Bias Mitigation...
# [LightGBM] [Info] Number of positive: 8415, number of negative: 8415
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015363 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3697
# [LightGBM] [Info] Number of data points in the train set: 16830, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.485235 -> initscore=-0.059078
# [LightGBM] [Info] Start training from score -0.059078
# Classification Report for LightGBM on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.62      0.87      0.72      2615
#            1       0.79      0.47      0.59      2652
#
#     accuracy                           0.67      5267
#    macro avg       0.70      0.67      0.66      5267
# weighted avg       0.70      0.67      0.66      5267
#
# ROC-AUC Score for LightGBM on Variant V Dataset: 0.75
#
# Training and Evaluating XGBoost on Variant V dataset with Bias Mitigation...
# /opt/conda/lib/python3.10/site-packages/fairlearn/postprocessing/_interpolated_thresholder.py:154: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.17455027e-04 2.17455027e-04 2.17455027e-04 ... 2.17455027e-04
#  9.93202777e-01 2.17455027e-04]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   positive_probs[sensitive_feature_vector == a] = interpolated_predictions[
# Classification Report for XGBoost on Variant V Dataset with Bias Mitigation:
#               precision    recall  f1-score   support
#
#            0       0.63      0.85      0.72      2615
#            1       0.77      0.51      0.62      2652
#
#     accuracy                           0.68      5267
#    macro avg       0.70      0.68      0.67      5267
# weighted avg       0.70      0.68      0.67      5267
#
# ROC-AUC Score for XGBoost on Variant V Dataset: 0.73
#
# Model Training and Evaluation Completed.

# %%
# Convert all metrics results to DataFrame for visualization
all_metrics_df = pd.DataFrame(all_metrics_results)
bias_summary = pd.DataFrame(bias_metrics_results)

# Print All Metrics Summary
print("\nAll Metrics Summary:")
print(all_metrics_df)
# Out:
# All Metrics Summary:
#         Dataset                  Model  Accuracy  F1 Score ROC-AUC Score  \
# 0          Base    Logistic Regression  0.773029  0.784749       0.85918
# 1          Base                    KNN  0.695550  0.704881      0.805919
# 2          Base          Random Forest  0.790203  0.808549      0.870793
# 3          Base   Gaussian Naive Bayes  0.762490  0.780444      0.817851
# 4          Base  Bernoulli Naive Bayes  0.763466  0.790890      0.834977
# 5          Base                    SVM  0.795863  0.816556      0.870002
# 6          Base         Neural Network  0.794692  0.812277           N/A
# 7          Base               LightGBM  0.804059  0.820778       0.88266
# 8          Base                XGBoost  0.782397  0.801070      0.870641
# 9     Variant I    Logistic Regression  0.760343  0.769951      0.845725
# 10    Variant I                    KNN  0.639344  0.605634      0.796306
# 11    Variant I          Random Forest  0.793130  0.814361      0.870951
# 12    Variant I   Gaussian Naive Bayes  0.745511  0.762217      0.811603
# 13    Variant I  Bernoulli Naive Bayes  0.771858  0.795092       0.83968
# 14    Variant I                    SVM  0.788447  0.810490      0.865942
# 15    Variant I         Neural Network  0.787080  0.807753           N/A
# 16    Variant I               LightGBM  0.806206  0.822139       0.88767
# 17    Variant I                XGBoost  0.770882  0.788163      0.861768
# 18   Variant II    Logistic Regression  0.784348  0.798762      0.867693
# 19   Variant II                    KNN  0.713505  0.725299      0.813218
# 20   Variant II          Random Forest  0.800156  0.818633      0.881531
# 21   Variant II   Gaussian Naive Bayes  0.766979  0.786862      0.825571
# 22   Variant II  Bernoulli Naive Bayes  0.779469  0.803067      0.850443
# 23   Variant II                    SVM  0.795667  0.821483      0.873933
# 24   Variant II         Neural Network  0.794496  0.812667           N/A
# 25   Variant II               LightGBM  0.809524  0.830024      0.889188
# 26   Variant II                XGBoost  0.784543  0.805016      0.877801
# 27  Variant III    Logistic Regression  0.827416  0.824348      0.909005
# 28  Variant III                    KNN  0.769508  0.767878      0.883445
# 29  Variant III          Random Forest  0.860262  0.861446      0.939037
# 30  Variant III   Gaussian Naive Bayes  0.814505  0.809737      0.876916
# 31  Variant III  Bernoulli Naive Bayes  0.798937  0.805080      0.876807
# 32  Variant III                    SVM  0.857034  0.858645      0.934033
# 33  Variant III         Neural Network  0.859692  0.859158           N/A
# 34  Variant III               LightGBM  0.870704  0.870852      0.947934
# 35  Variant III                XGBoost  0.863110  0.864804      0.942742
# 36   Variant IV    Logistic Regression  0.733055  0.716761      0.814989
# 37   Variant IV                    KNN  0.661667  0.655985       0.77253
# 38   Variant IV          Random Forest  0.747105  0.737278      0.823057
# 39   Variant IV   Gaussian Naive Bayes  0.707613  0.690887      0.768317
# 40   Variant IV  Bernoulli Naive Bayes  0.710272  0.707439      0.780886
# 41   Variant IV                    SVM  0.753180  0.754253      0.828717
# 42   Variant IV         Neural Network  0.744826  0.735433           N/A
# 43   Variant IV               LightGBM  0.762673  0.757752      0.844203
# 44   Variant IV                XGBoost  0.750522  0.743860      0.831361
# 45    Variant V    Logistic Regression  0.693754  0.639231      0.783696
# 46    Variant V                    KNN  0.675337  0.652298       0.77065
# 47    Variant V          Random Forest  0.678375  0.602161      0.782082
# 48    Variant V   Gaussian Naive Bayes  0.703057  0.658366      0.782592
# 49    Variant V  Bernoulli Naive Bayes  0.739510  0.730664      0.810628
# 50    Variant V                    SVM  0.703436  0.655796         0.783
# 51    Variant V         Neural Network  0.684830  0.621868           N/A
# 52    Variant V               LightGBM  0.669641  0.588847      0.753516
# 53    Variant V                XGBoost  0.678944  0.617507      0.734309
#
#     Demographic Parity Difference  Equalized Odds Difference
# 0                        0.543587                   0.468841
# 1                        0.174645                   0.339367
# 2                        0.624172                   0.572219
# 3                        0.563474                   0.449621
# 4                        0.544964                   0.488643
# 5                        0.585945                   0.518346
# 6                        0.597223                   0.533197
# 7                        0.881188                   0.647059
# 8                        0.454738                   0.435704
# 9                        0.552381                   0.527778
# 10                       0.262451                   0.414773
# 11                       0.480952                   0.363636
# 12                       0.857143                   0.687500
# 13                       0.460591                   0.489081
# 14                       0.871429                   0.625000
# 15                       0.566667                   0.583333
# 16                       0.871429                   0.562500
# 17                       0.742857                   0.500000
# 18                       0.509312                   0.335000
# 19                       0.338857                   0.255682
# 20                       0.525095                   0.340000
# 21                       0.795455                   0.369318
# 22                       0.544192                   0.340909
# 23                       0.498580                   0.365000
# 24                       0.495265                   0.342500
# 25                       0.840909                   0.555556
# 26                       0.727273                   0.333333
# 27                       0.497992                   0.445946
# 28                       0.231024                   0.294872
# 29                       0.679487                   0.442029
# 30                       0.670940                   0.418919
# 31                       0.645299                   0.470588
# 32                       0.640562                   0.442029
# 33                       0.399573                   0.290598
# 34                       0.679487                   0.471014
# 35                       0.495726                   0.352941
# 36                       0.488781                   0.583333
# 37                       0.323404                   0.442308
# 38                       0.723913                   0.987179
# 39                       0.446035                   0.435897
# 40                       0.460270                   0.551893
# 41                       0.654545                   0.692308
# 42                       0.501547                   0.955556
# 43                       0.469565                   0.935897
# 44                       0.380851                   0.880952
# 45                       0.447964                   0.603448
# 46                       0.202489                   0.722222
# 47                       0.386878                   0.672414
# 48                       0.251821                   0.750000
# 49                       0.346154                   0.722197
# 50                       0.506787                   0.724138
# 51                       0.540724                   0.732759
# 52                       0.420814                   0.689655
# 53                       0.479638                   0.693966

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting Demographic Parity Difference by Dataset and Model
plt.figure(figsize=(12, 6))
sns.barplot(data=all_metrics_df, x='Dataset', y='Demographic Parity Difference', hue='Model')
plt.title('Demographic Parity Difference by Dataset and Model')
plt.xlabel('Dataset')
plt.ylabel('Demographic Parity Difference')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plotting Equalized Odds Difference by Dataset and Model
plt.figure(figsize=(12, 6))
sns.barplot(data=all_metrics_df, x='Dataset', y='Equalized Odds Difference', hue='Model')
plt.title('Equalized Odds Difference by Dataset and Model')
plt.xlabel('Dataset')
plt.ylabel('Equalized Odds Difference')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plotting Accuracy by Dataset and Model
plt.figure(figsize=(12, 6))
sns.barplot(data=all_metrics_df, x='Dataset', y='Accuracy', hue='Model')
plt.title('Accuracy by Dataset and Model')
plt.xlabel('Dataset')
plt.ylabel('Accuracy')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plotting F1 Score by Dataset and Model
plt.figure(figsize=(12, 6))
sns.barplot(data=all_metrics_df, x='Dataset', y='F1 Score', hue='Model')
plt.title('F1 Score by Dataset and Model')
plt.xlabel('Dataset')
plt.ylabel('F1 Score')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plotting ROC-AUC Score by Dataset and Model (if applicable)
roc_auc_df = all_metrics_df[all_metrics_df['ROC-AUC Score'] != 'N/A']
if not roc_auc_df.empty:
    plt.figure(figsize=(12, 6))
    sns.barplot(data=roc_auc_df, x='Dataset', y='ROC-AUC Score', hue='Model')
    plt.title('ROC-AUC Score by Dataset and Model')
    plt.xlabel('Dataset')
    plt.ylabel('ROC-AUC Score')
    plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
# Plotting All Metrics Summary
fig, axs = plt.subplots(1, 3, figsize=(24, 8))

# Plot Accuracy for all datasets and models
sns.barplot(data=all_metrics_df, x='Dataset', y='Accuracy', hue='Model', ax=axs[0], palette='viridis')
axs[0].set_title('Accuracy by Dataset and Model')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Dataset')
axs[0].tick_params(axis='x', rotation=45)
axs[0].grid(axis='y')

# Plot F1 Score for all datasets and models
sns.barplot(data=all_metrics_df, x='Dataset', y='F1 Score', hue='Model', ax=axs[1], palette='magma')
axs[1].set_title('F1 Score by Dataset and Model')
axs[1].set_ylabel('F1 Score')
axs[1].set_xlabel('Dataset')
axs[1].tick_params(axis='x', rotation=45)
axs[1].grid(axis='y')

# Plot ROC-AUC Score for all datasets and models (if applicable)
sns.barplot(data=all_metrics_df[all_metrics_df['ROC-AUC Score'] != 'N/A'], x='Dataset', y='ROC-AUC Score', hue='Model', ax=axs[2], palette='plasma')
axs[2].set_title('ROC-AUC Score by Dataset and Model')
axs[2].set_ylabel('ROC-AUC Score')
axs[2].set_xlabel('Dataset')
axs[2].tick_params(axis='x', rotation=45)
axs[2].grid(axis='y')

plt.tight_layout()
plt.show()

# Plotting Bias Metrics
fig, axs = plt.subplots(1, 2, figsize=(18, 8))

# Plot Demographic Parity Difference for all datasets and models
sns.barplot(data=bias_summary, x='Dataset', y='Demographic Parity Difference', hue='Model', ax=axs[0], palette='Blues')
axs[0].set_title('Demographic Parity Difference by Dataset and Model')
axs[0].set_ylabel('Demographic Parity Difference')
axs[0].set_xlabel('Dataset')
axs[0].tick_params(axis='x', rotation=45)
axs[0].grid(axis='y')

# Plot Equalized Odds Difference for all datasets and models
sns.barplot(data=bias_summary, x='Dataset', y='Equalized Odds Difference', hue='Model', ax=axs[1], palette='Greens')
axs[1].set_title('Equalized Odds Difference by Dataset and Model')
axs[1].set_ylabel('Equalized Odds Difference')
axs[1].set_xlabel('Dataset')
axs[1].tick_params(axis='x', rotation=45)
axs[1].grid(axis='y')

plt.tight_layout()
plt.show()
